# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('iris_data_with_missing_values.csv', header = None)

# %%
df.columns = ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Class']

# %%
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    147.000000   147.000000    147.000000   148.000000
# mean       5.908844     3.138776      3.836735     1.197297
# std        1.116190     1.226111      1.821187     0.768243
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max       15.000000    17.000000     10.000000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Class            object
# dtype: object

# %%
df.head(20)
# Out:
#     Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4          10.0          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
(df['Sepal_Length'] == 0).sum()
# Out:
# 0

# %%
(df['Sepal_Width'] == 0).sum()
# Out:
# 0

# %%
(df['Petal_Length'] == 0).sum()
# Out:
# 0

# %%
(df['Petal_Width'] == 0).sum()
# Out:
# 0

# %%
(df['Class'] == None).sum()
# Out:
# 0

# %%
df['Sepal_Length'].isnull().sum()
# Out:
# 3

# %%
df['Sepal_Width'].isnull().sum()
# Out:
# 3

# %%
df['Petal_Length'].isnull().sum()
# Out:
# 3

# %%
df['Petal_Width'].isnull().sum()
# Out:
# 2

# %%
df['Class'].isnull().sum()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# Sepal_Length    3
# Sepal_Width     3
# Petal_Length    3
# Petal_Width     2
# Class           3
# dtype: int64

# %%
(df == 0).sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Class           0
# dtype: int64

# %%
df.shape[0] - df.dropna().shape[0]
# Counting number of rows having missing values
# Out:
# 13

# %%
df_remove = df.dropna()

# %%
df_remove
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
#
# [137 rows x 5 columns]

# %%
df_remove.shape
# Out:
# (137, 5)

# %%
list = ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width']

# %%
df.fillna(df.mean(), inplace = True)
# Out:
# C:\Users\UDAY MITTAL\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df['Class'].fillna('missing', inplace = True)

# %%
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0             5.1     3.500000           1.4          0.2     Iris-setosa
# 1             4.9     3.000000           1.4          0.2     Iris-setosa
# 2             4.7     3.200000           1.3          0.2     Iris-setosa
# 3             4.6     3.100000           1.5          0.2     Iris-setosa
# 4             5.0     3.600000           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7     3.000000           5.2          2.3  Iris-virginica
# 146           6.3     2.500000           5.0          1.9  Iris-virginica
# 147           6.5     3.000000           5.2          2.0  Iris-virginica
# 148           6.2     3.400000           5.4          2.3  Iris-virginica
# 149           5.9     3.138776           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df[df.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Sepal_Length, Sepal_Width, Petal_Length, Petal_Width, Class]
# Index: []

# %%
df_without = df.sample(frac = 0.20, replace = False)
df_with = df.sample(frac = 0.20, replace = True)

# %%
df_without
# Without Replacement
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width            Class
# 138      6.000000          3.0           4.8          1.8   Iris-virginica
# 129      7.200000          3.0           5.8          1.6   Iris-virginica
# 17       5.100000          3.5           1.4          0.3      Iris-setosa
# 53       5.500000          2.3           4.0          1.3  Iris-versicolor
# 56       6.300000          3.3           4.7          1.6  Iris-versicolor
# 70       5.900000          3.2           4.8          1.8  Iris-versicolor
# 115      6.400000          3.2           5.3          2.3   Iris-virginica
# 65       6.700000          3.1           4.4          1.4  Iris-versicolor
# 72       6.300000          2.5           4.9          1.5  Iris-versicolor
# 2        4.700000          3.2           1.3          0.2      Iris-setosa
# 87       6.300000          2.3           4.4          1.3  Iris-versicolor
# ...

# %%
df_with
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width            Class
# 22       4.600000     3.600000           1.0          0.2      Iris-setosa
# 148      6.200000     3.400000           5.4          2.3   Iris-virginica
# 37       4.900000     3.100000           1.5          0.1      Iris-setosa
# 105      7.600000     3.000000           6.6          2.1   Iris-virginica
# 15       5.700000     3.138776           1.5          0.4      Iris-setosa
# 1        4.900000     3.000000           1.4          0.2      Iris-setosa
# 45       4.800000     3.000000           1.4          0.3          missing
# 94       5.600000     2.700000           4.2          1.3  Iris-versicolor
# 139      6.900000     3.100000           5.4          2.1   Iris-virginica
# 105      7.600000     3.000000           6.6          2.1   Iris-virginica
# 94       5.600000     2.700000           4.2          1.3  Iris-versicolor
# ...

# %%
import matplotlib as mp

# %%
for i in list:
    df.plot(i, kind = 'bar')
# df.plot(kind = 'bar')

# %%
df_n = pd.read_csv('iris_data_with_missing_values.csv', header = None)

# %%
df_n.columns = ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Class']

# %%
df_n.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
list = ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width']

# %%
for i in list:
    mean = df_n[i].mean()
    sd = df_n[i].std()
    df_n[i] = (df_n[i] - mean) / sd

# %%
display(df_n)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0       -0.724647     0.294610     -1.337992    -1.298154     Iris-setosa
# 1       -0.903828    -0.113183     -1.337992    -1.298154     Iris-setosa
# 2       -1.083009     0.049934     -1.392902    -1.298154     Iris-setosa
# 3       -1.172599    -0.031625     -1.283083    -1.298154     Iris-setosa
# 4       -0.814237     0.376169     -1.337992    -1.298154     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145      0.708801    -0.113183      0.748559     1.435357  Iris-virginica
# 146      0.350439    -0.520977      0.638740     0.914689  Iris-virginica
# 147      0.529620    -0.113183      0.748559     1.044856  Iris-virginica
# 148      0.260848     0.213051      0.858377     1.435357  Iris-virginica
# 149     -0.007923          NaN      0.693649     0.784521  Iris-virginica
#
# [150 rows x 5 columns]

# %%
for i in list:
    print(i, ' ', df_n[i].max(), ' ', df_n[i].min())
# Out:
# Sepal_Length   8.144810741345875   -1.441370652744913
# Sepal_Width   11.305028599637572   -0.9287700174613917
# Petal_Length   3.3842016138847995   -1.557629219635721
# Petal_Width   1.6956917830424965   -1.4283212944299881

# %%
for i in list:
    outlier = []
    for j in range(len(df_n[i])):
        if (df_n[i][j] > 3 or df_n[i][j] < -3):
            print(df.iloc[j, :])
# Out:
# Sepal_Length           15.0
# Sepal_Width             3.1
# Petal_Length            1.6
# Petal_Width             0.2
# Class           Iris-setosa
# Name: 30, dtype: object
# Sepal_Length                5.6
# Sepal_Width                17.0
# Petal_Length                3.6
# Petal_Width                 1.3
# Class           Iris-versicolor
# Name: 64, dtype: object
# Sepal_Length            5.0
# Sepal_Width             3.4
# Petal_Length           10.0
# Petal_Width             0.2
# Class           Iris-setosa
# Name: 7, dtype: object

# %%
df_min = df.copy()

# %%
df_min.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
for i in list:
    df_min[i] = (df_min[i] - df_min[i].min()) / (df_min[i].max() - df_min[i].min())

# %%
print(df_min)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0        0.074766     0.100000      0.044444     0.041667     Iris-setosa
# 1        0.056075     0.066667      0.044444     0.041667     Iris-setosa
# 2        0.037383     0.080000      0.033333     0.041667     Iris-setosa
# 3        0.028037     0.073333      0.055556     0.041667     Iris-setosa
# 4        0.065421     0.106667      0.044444     0.041667     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145      0.224299     0.066667      0.466667     0.916667  Iris-virginica
# 146      0.186916     0.033333      0.444444     0.750000  Iris-virginica
# 147      0.205607     0.066667      0.466667     0.791667  Iris-virginica
# 148      0.177570     0.093333      0.488889     0.916667  Iris-virginica
# 149      0.149533     0.075918      0.455556     0.708333  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_copy = df.copy()

# %%
bins = [0, 0.5, 1.5, 2.5, 4.5, 6.5]

# %%
df_copy['Petal_Length'] = np.digitize(df_copy['Petal_Length'], bins, right = False)

# %%
df_copy
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0             5.1     3.500000             5          0.2     Iris-setosa
# 1             4.9     3.000000             5          0.2     Iris-setosa
# 2             4.7     3.200000             5          0.2     Iris-setosa
# 3             4.6     3.100000             5          0.2     Iris-setosa
# 4             5.0     3.600000             5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7     3.000000             5          2.3  Iris-virginica
# 146           6.3     2.500000             5          1.9  Iris-virginica
# 147           6.5     3.000000             5          2.0  Iris-virginica
# 148           6.2     3.400000             5          2.3  Iris-virginica
# 149           5.9     3.138776             5          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.corr()
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Sepal_Length      1.000000    -0.045652      0.509271     0.518591
# Sepal_Width      -0.045652     1.000000     -0.125489    -0.109536
# Petal_Length      0.509271    -0.125489      1.000000     0.873729
# Petal_Width       0.518591    -0.109536      0.873729     1.000000
